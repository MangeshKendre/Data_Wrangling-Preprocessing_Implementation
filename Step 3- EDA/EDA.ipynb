# %% [markdown]
# # Understanding dataset

# %%
# !pip install pandas

# %%
#importing libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns



# %time     # processing time
#import warnings            ---for warnings 
#warnings.filterwarnings('ignore')


'''
##for unicode decode error --put encoding='whatever/utf8/..'
#cheak unicode by below code 
import chardet
with open('zomato.xlsx', 'rb') as rawdata:
    result = chardet.detect(rawdata.read(100000))
result
'''

# %%
#reading dataset

df=pd.read_csv("data.csv")   #,low_memory=False
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#dataset size


df.shape                    #(rows,columns)
# Out:
# (891, 12)

# %%
# how dataset looks 

#df.head()    #shows first 5 rows by default


#shows random rows from dataset
df.sample(10)
# Out:
#      PassengerId  Survived  Pclass  \
# 167          168         0       3
# 773          774         0       3
# 36            37         1       3
# 677          678         1       3
# 622          623         1       3
# 775          776         0       3
# 846          847         0       3
# 48            49         0       3
# 728          729         0       2
# 560          561         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 167  Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 773                                  Elias, Mr. Dibo    male   NaN      0
# 36                                  Mamee, Mr. Hanna    male   NaN      0
# 677                          Turja, Miss. Anna Sofia  female  18.0      0
# 622                                 Nakid, Mr. Sahid    male  20.0      1
# 775          Myhrman, Mr. Pehr Fabian Oliver Malkolm    male  18.0      0
# ...

# %%
#datatypes of columns

df.info()

#objects/string----(0,1,2,3),int,float,datetime

#to save memory for large datset ,we can convert some features datatype float---->int(eg--age 22.2-->22)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#missing value

df.isna().sum()
#df.isna().sum()/len(df)         #in %
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#mathamatical dataset

df.describe()  #usefull for numerical features


#mean 
#median
#mode
#standard deviation
#25,50,75%
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
#cheaking duplicate values

df.duplicated().sum()
# Out:
# 0

# %%
#correlation between features

df.corr()     #Pearson correlation coefficient    -1(negetively correlation/correlated) to +1(positive correlation)
                                               #   eg x and y =-0.4 i.e neg corr--x increases then y decreases
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp     Parch  \
# PassengerId     1.000000 -0.005007 -0.035144  0.036847 -0.057527 -0.001652
# Survived       -0.005007  1.000000 -0.338481 -0.077221 -0.035322  0.081629
# Pclass         -0.035144 -0.338481  1.000000 -0.369226  0.083081  0.018443
# Age             0.036847 -0.077221 -0.369226  1.000000 -0.308247 -0.189119
# SibSp          -0.057527 -0.035322  0.083081 -0.308247  1.000000  0.414838
# Parch          -0.001652  0.081629  0.018443 -0.189119  0.414838  1.000000
# Fare            0.012658  0.257307 -0.549500  0.096067  0.159651  0.216225
#
#                  Fare
# PassengerId  0.012658
# Survived     0.257307
# Pclass      -0.549500
# Age          0.096067
# SibSp        0.159651
# Parch        0.216225
# Fare         1.000000

# %%
df.corr()['Pclass']     #relation with target feature

#PassengerId   -0.035144--  this decrease then target feature increases 
#Parch          0.018443--  this increases then target feature increases
# Out:
# PassengerId   -0.035144
# Survived      -0.338481
# Pclass         1.000000
# Age           -0.369226
# SibSp          0.083081
# Parch          0.018443
# Fare          -0.549500
# Name: Pclass, dtype: float64

# %%
#columns

col_list = list(df.columns)         #df.columns.to_list()
col_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [1], line 3
#       1 #columns
# ----> 3 col_list = list(df.columns)         #df.columns.to_list()
#       4 col_list
#
# NameError: name 'df' is not defined

# %%
mis_p=df.isna().sum()/len(df)*100
dict(mis_p.to_dict())

# %%
#datatype

#float64(3), int64(4), object(13),datetime64[ns]

col_object=[]
col_float=[]
col_integer=[]
col_other=[]



for i in col_list:
    
    if df[i].dtype==object:
        col_object.append(i) 
    elif df[i].dtype==float:
        col_float.append(i)
    elif df[i].dtype in (np.int8,np.int32,np.int64):
        col_integer.append(i)    
    else: 
        col_other.append(i)  
print('object=',col_object)
print()
print('int=',col_integer)  
print()
print('float=',col_float)
print()
print('other datatype column=',col_other)

# %%
#categorical and numerical columns

#-----usefull for eda part
#-----usefull for feature enginneering part

categorical_col=list(col_object)
categorical_col

# %%
numerical_col=col_other+col_float
numerical_col

# %% [raw]
# EDA
#
# >univariate analysis--analysis of only one feature
#
# >bivariate analysis--analysis of two features
#
# >multivariate analysis--analysis of two or more fatures
#
# Data
#
# >numerical--age,wt,height
# >categorical--country,gender,religion

# %% [markdown]
# # Univariate analsys

# %% [markdown]
# # 1. Categorical Data   -   countplot,piechart

# %% [markdown]
# # Countplot

# %%
sns.countplot(df['Embarked'])
df['Embarked'].value_counts()

#plt.title("Linear")---give title

#plt.xlabel('Months')----x coordinate
#plt.ylabel('Books Read---y coordinate

#plt.show() 

#plt.savefig('insights_from_data/embarked.png')
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Linear')

# %% [markdown]
# # PieChart

# %%
df['Embarked'].value_counts().plot(kind='pie',autopct='%.2f')     #autopct='%.2f'  -----used to see percentage
# Out:
# <AxesSubplot:ylabel='Embarked'>

# %% [markdown]
# # 2. Numerical Data

# %% [raw]
# df['Age'].min()
# df['Age'].max()
# df['Age'].mean()
# df['Age'].skew()

# %% [markdown]
# # Histogram

# %%
plt.hist(df['Age'])
#plt.hist(df['Age'],bins=5)

#min age-0 
#max age-80 
#age 0 to 20 -few
#age 40 to 80-few
#age 30 to 40-more
# Out:
# (array([ 54.,  46., 177., 169., 118.,  70.,  45.,  24.,   9.,   2.]),
#  array([ 0.42 ,  8.378, 16.336, 24.294, 32.252, 40.21 , 48.168, 56.126,
#         64.084, 72.042, 80.   ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # Distplot

# %%
sns.distplot(df['Age'])

#this blue line is KDE plot(kernel density estimation) shows PDF-probablity distribution function

#histogram shows exact numbers while this kde plot shows probablity curve i.e probality for age 60 is 0.5%




#distogram also shows skewness of feature

#df['Age'].skew()

#+ve---+ve skewed
#-ve---- -ve skewed
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [markdown]
# # Boxplot

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [raw]
# # boxplot used to see -- outliers(any point below calculated min and any point above calculated max)
#
# minimum--q1-1.5*iqr
# maximum--q1+1.5*iqr
# iqr
# q1-25 percentile
# q2-75 percentile
# median

# %%
sns.boxplot(df['Age'])
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Age'>

# %% [markdown]
# # bivariate and multivariate analsys

# %%
#inbuild datasets

tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
iris = sns.load_dataset('iris')

tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # 1. Scatterplot (Numerical - Numerical  features)

# %%
sns.scatterplot(tips['total_bill'],tips['tip'],hue=tips['sex'],style=tips['smoker'],size=tips['size'])

#sns.scatterplot(x axis,y axis)
#hue=df['col']       ----categorical--yes/no,male/female       
#style=df['col']     ----categorical--yes/no,male/female 
#size=df['col']      ----numerical
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # 2. Bar Plot (Numerical - Categorical)

# %%
sns.barplot(df['Pclass'],df['Age'],hue=df['Sex'])

#black lines are called confidence intervals
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(df['Sex'],df['Age'],hue=df['Survived'])
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Sex', ylabel='Age'>

# %% [markdown]
# # 4. Distplot (Numerical - Categorical)

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Age', ylabel='Density'>

# %% [markdown]
# # 5. HeatMap (Categorical - Categorical)

# %%
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <AxesSubplot:xlabel='Survived', ylabel='Pclass'>

# %%
 # shows % 
    
(df.groupby('Pclass').mean()['Survived']*100)
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
((df.groupby('Pclass').mean()['Survived']*100).plot(kind='bar'))
# Out:
# <AxesSubplot:xlabel='Pclass'>

# %% [markdown]
# # 6. ClusterMap (Categorical - Categorical)

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']))

#this connected white lines are called dendograms---indicates closeness and links .

# %% [markdown]
# # 7. Pairplot

# %%
# pairplot is collection of scatter plot
#automatically detect numerical features and gives its scatter plot

sns.pairplot(iris,hue='species')

# %% [markdown]
# # 8. Lineplot (Numerical - Numerical)

# %%
#join points of scatter plot
#when to use --when x axis quantity is time based---> time/year/month/date

flights.groupby('year').sum().reset_index()
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
#put time format in x axis

new = flights.groupby('year').sum().reset_index()
sns.lineplot(new['year'],new['passengers'])
# Out:
# C:\Users\admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# <AxesSubplot:xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
