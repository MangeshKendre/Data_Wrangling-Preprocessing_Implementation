# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Curse of dimensionality

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [raw]
# Curse of Dimensionality describes the explosive nature of increasing data dimensions and its resulting exponential increase in computational efforts required for its processing and/or analysis
#
# high dimension--sparsity
# eg 5 pts in  1d=5 pts,in 2d=25,in 3d=125(incresed sparsity)
#
#
# high dimensional data
# -images
# -text
#
# why need to be handled?
#
# performance of algorithm decreses
# computation increases
#
#
# solutions ---->dimensionality reduction
#
#
# 1. feature extraction(f1,f2,f3,f4....f10---->e1,e2,e3,e4... ==new features created)
# --PCA
# --lda
# --tsne
#
# 2. feature selection (f1,f2,f3,f4....f10---->f1,f3,f4,... ==features amoung them selected)
# -forward selection
# -backward elimination

# %% [raw]
# PCA(principle componenet analysis)
#
# -feature extraction tehnique---to reduce curse of dimentiobalty---accuracy of model increase
# -unsupervised(only input no output)
# -high dimension ---to--lower dimensional as posible(keeping essence of data)
# -results of model will be same ,only dimensions will be reduced
#
# benifits
# -faster execution of model
# -visualisation
#
#
# eg     no rooms,no grossery shops--price
# spread     d    >   di   ---------------------so we will select no rooms
#
#        no rooms,no washrooms--price
# if         d   =   di    -----------unable to decide-----> here PCA comes
# in PCA, here new feature created
#       size of flat -- price
#
# if axis are rotated,2 new axis created
# pca1
# pca2
# after axis rotation,d>di -------d will be used
# always original features>no pca
#
#
# variance
# eg    -5  0  5 ----mean 0
#       -10 0  10 ---mean 0
# to diffreantiate ,we need variance
#
# variance=sumatn ( xi-xi--- sd)**2  / n
#
# endgoal ---maximise the variance
#
# #spread is not variance
# spread propotional to variance

# %% [markdown]
# ## ![image.png](attachment:image.png)

# %% [markdown]
# # ![image.png](attachment:image.png)

# %% [raw]
# x-original point
# x1-projected point
# u-unit vector(pca 1)
#
# each point on unit vector(U)--x1=(u transpose).x    x2=(u transpose).x
#
# for each point we will gwt seperate unit vector and variance(scaler quantityin no)
#
# endgoal---->unit vector with high variance
#
# variance=summn( x-x bar(mean)) **2/n
#
# max variance=summn 1 to n(u transpose x1- u tranpose x bar)**2/n

# %%
upto 13 min  part 2

# %%
import pandas as pd

# %%
import vaex
